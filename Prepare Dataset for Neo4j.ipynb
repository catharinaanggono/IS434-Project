# %%
import pandas as pd

# load in the csv file
tweets = pd.read_csv('./Labelled Dataset/jan_labelled.csv')

# create a dataframe
df = pd.DataFrame(tweets)
df.rename(columns={'user.screen_name': 'user_name', 'user.id_str': 'user_id', 'Johnny Depp sentiment': 'jd_sentiment', 'Amber Heard sentiment': 'ah_sentiment'}, inplace=True)

tweets = pd.read_csv('./Labelled Dataset/feb_labelled.csv')
df_feb = pd.DataFrame(tweets)
df_feb.rename(columns={'user.screen_name': 'user_name', 'user.id_str': 'user_id'}, inplace=True)

tweets = pd.read_csv('./Labelled Dataset/mar_labelled.csv')
df_mar = pd.DataFrame(tweets)
df_mar.rename(columns={'user.screen_name': 'user_name', 'user.id_str': 'user_id'}, inplace=True)

tweets = pd.read_csv('./Labelled Dataset/pre_apr_labelled.csv')
df_apr = pd.DataFrame(tweets)
df_apr.rename(columns={'user.screen_name': 'user_name', 'user.id_str': 'user_id'}, inplace=True)

tweets = pd.read_csv('./Labelled Dataset/apr_labelled.csv')
df_apr2 = pd.DataFrame(tweets)

tweets = pd.read_csv('./Labelled Dataset/may_labelled.csv')
df_may = pd.DataFrame(tweets)

tweets = pd.read_csv('./Labelled Dataset/jun_labelled.csv')
df_june = pd.DataFrame(tweets)

tweets = pd.read_csv('./Labelled Dataset/jul_labelled.csv')
df_july = pd.DataFrame(tweets)

tweets = pd.read_csv('./Labelled Dataset/aug_labelled.csv')
df_aug = pd.DataFrame(tweets)

# %%
df
# Out:
#              id_str                 created_at  \
# 0      1.477505e+18  2022-01-02 05:00:13+00:00
# 1      1.477504e+18  2022-01-02 04:55:19+00:00
# 2      1.477500e+18  2022-01-02 04:39:41+00:00
# 3      1.477498e+18  2022-01-02 04:31:26+00:00
# 4      1.477496e+18  2022-01-02 04:26:25+00:00
# ...             ...                        ...
# 13892  1.479736e+18  2022-01-08 08:46:46+00:00
# 13893  1.479736e+18  2022-01-08 08:44:45+00:00
# 13894  1.479736e+18  2022-01-08 08:44:11+00:00
# 13895  1.479735e+18  2022-01-08 08:41:42+00:00
# 13896  1.479735e+18  2022-01-08 08:40:02+00:00
#
#                                                full_text lang  \
# 0      @la77465262 @Melinda15199317 @Dior So why is #...   en
# 1      Only thing I want them to leave alone is the f...   en
# 2      @soldierboy43001 @ZakReckless Yeah but Snyder ...   en
# 3      @IIMissMax @bg98021 @GerberKawasaki You forgot...   en
# 4      I never seen Aquaman nor will I because Amber ...   en
# ...

# %%
df_july
# Out:
#        Unnamed: 0                 created_at        id_str        user_name  \
# 0               0  2022-07-10 23:59:48+00:00  1.546283e+18        reenpur78
# 1               1  2022-07-10 23:59:39+00:00  1.546283e+18      KevinSipos2
# 2               2  2022-07-10 23:58:03+00:00  1.546283e+18        S_7_3_V_3
# 3               3  2022-07-10 23:57:21+00:00  1.546282e+18      Daniboy_CFC
# 4               4  2022-07-10 23:57:07+00:00  1.546282e+18       9breakingn
# ...           ...                        ...           ...              ...
# 75185       75185  2022-07-09 00:00:40+00:00  1.545559e+18  cooking_lowcarb
# 75186       75186  2022-07-09 00:00:22+00:00  1.545558e+18        TalyaHere
# 75187       75187  2022-07-09 00:00:22+00:00  1.545558e+18     irenevautour
# 75188       75188  2022-07-09 00:00:04+00:00  1.545558e+18  scienceLeMagazi
# 75189       75189  2022-07-09 00:00:00+00:00  1.545558e+18   amberheardhour
#
# ...

# %%
df = df.append(df_feb)
df = df.append(df_mar)
df = df.append(df_apr)
df = df.append(df_apr2)
df = df.append(df_may)
df = df.append(df_june)
df = df.append(df_july)
df = df.append(df_aug)
# Out:
# C:\Users\catharinaa.2019\AppData\Local\Temp\ipykernel_16808\3580591428.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_feb)
# C:\Users\catharinaa.2019\AppData\Local\Temp\ipykernel_16808\3580591428.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_mar)
# C:\Users\catharinaa.2019\AppData\Local\Temp\ipykernel_16808\3580591428.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_apr)
# C:\Users\catharinaa.2019\AppData\Local\Temp\ipykernel_16808\3580591428.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_apr2)
# ...

# %%
df
# Out:
#              id_str                 created_at  \
# 0      1.477505e+18  2022-01-02 05:00:13+00:00
# 1      1.477504e+18  2022-01-02 04:55:19+00:00
# 2      1.477500e+18  2022-01-02 04:39:41+00:00
# 3      1.477498e+18  2022-01-02 04:31:26+00:00
# 4      1.477496e+18  2022-01-02 04:26:25+00:00
# ...             ...                        ...
# 64162  1.557882e+18  2022-08-12 00:07:51+00:00
# 64163  1.557881e+18  2022-08-12 00:06:21+00:00
# 64164  1.557880e+18  2022-08-12 00:03:39+00:00
# 64165  1.557880e+18  2022-08-12 00:02:46+00:00
# 64166  1.557880e+18  2022-08-12 00:00:01+00:00
#
#                                                full_text lang  \
# 0      @la77465262 @Melinda15199317 @Dior So why is #...   en
# 1      Only thing I want them to leave alone is the f...   en
# 2      @soldierboy43001 @ZakReckless Yeah but Snyder ...   en
# 3      @IIMissMax @bg98021 @GerberKawasaki You forgot...   en
# 4      I never seen Aquaman nor will I because Amber ...   en
# ...

# %%
# get the frequency count of tweet id

tweet_id_with_frequency = df['in_reply_to_status_id_str'].value_counts().to_frame()
tweet_id_with_frequency
# Out:
#               in_reply_to_status_id_str
# 1.520000e+18                        814
# 1.559578e+18                        240
# 1.483652e+18                        234
# 1.549572e+18                        199
# 1.532837e+18                        182
# ...                                 ...
# 1.530905e+18                          1
# 1.530842e+18                          1
# 1.530999e+18                          1
# 1.530972e+18                          1
# 1.557878e+18                          1
#
# [152801 rows x 1 columns]

# %%
# drop the ids with count less than 30

tweet_id_with_frequency.drop(tweet_id_with_frequency[tweet_id_with_frequency['in_reply_to_status_id_str'] <= 30].index, inplace = True)
tweet_id_with_frequency
# Out:
#               in_reply_to_status_id_str
# 1.520000e+18                        814
# 1.559578e+18                        240
# 1.483652e+18                        234
# 1.549572e+18                        199
# 1.532837e+18                        182
# ...                                 ...
# 1.537811e+18                         31
# 1.532095e+18                         31
# 1.523575e+18                         31
# 1.535803e+18                         31
# 1.533969e+18                         31
#
# [158 rows x 1 columns]

# %%
# create a list from the tweet ids

tweet_id_with_frequency_list = tweet_id_with_frequency.in_reply_to_status_id_str.keys().tolist()

# %%
tweet_id_with_frequency_list
# Out:
# [1.52e+18,
#  1.559578215735247e+18,
#  1.4836521857579295e+18,
#  1.549572341528953e+18,
#  1.532837189033157e+18,
#  1.559578201885741e+18,
#  1.534235698156347e+18,
#  1.472990607610192e+18,
#  1.540394329042215e+18,
#  1.538944773238792e+18,
#  1.510419595043115e+18,
#  1.523465632502907e+18,
#  1.528262522490323e+18,
#  1.531214001526424e+18,
#  1.531263324167471e+18,
#  1.536311999369445e+18,
#  1.535731339831702e+18,
#  1.555977005492949e+18,
#  1.54401820086143e+18,
#  1.539300637480997e+18,
#  1.549454023392199e+18,
#  1.560325664850551e+18,
#  1.54691730905863e+18,
#  1.559578220621701e+18,
#  1.524076316735255e+18,
#  1.496475913889923e+18,
#  1.538432347162436e+18,
#  1.557943469984956e+18,
#  1.560309875850285e+18,
#  1.4980057657804923e+18,
#  1.532767328731111e+18,
#  1.557846831404573e+18,
#  1.522595096968974e+18,
#  1.540736491269214e+18,
#  1.545204836844585e+18,
#  1.512889568344826e+18,
#  1.532377393553215e+18,
#  1.5128766559534612e+18,
# ...

# %%
high_centrality_df = df[df['in_reply_to_status_id_str'].isin(tweet_id_with_frequency_list)]

# %%
high_centrality_df
# Out:
#              id_str                 created_at  \
# 1550   1.481747e+18  2022-01-13 21:58:11+00:00
# 1551   1.481747e+18  2022-01-13 21:57:01+00:00
# 1799   1.482517e+18  2022-01-16 00:55:13+00:00
# 1897   1.481765e+18  2022-01-13 23:07:22+00:00
# 1901   1.481715e+18  2022-01-13 19:51:10+00:00
# ...             ...                        ...
# 64116  1.557888e+18  2022-08-12 00:33:37+00:00
# 64119  1.557887e+18  2022-08-12 00:31:33+00:00
# 64124  1.557887e+18  2022-08-12 00:29:19+00:00
# 64128  1.557886e+18  2022-08-12 00:27:31+00:00
# 64152  1.557883e+18  2022-08-12 00:12:53+00:00
#
#                                                full_text lang  \
# 1550                  @IGN Amber heard killed this movie   en
# 1551   @IGN Nope. Anything with Amber Heard is a hard...   en
# 1799   Here is my latest appreciative tweet for one o...   en
# 1897   @IGN I feel bad for the other actors because a...   en
# 1901                             @IGN Remove amber heard   en
# ...

# %%
high_centrality_df.to_csv("Master_High_Centrality_Dataset.csv", index=False, encoding='utf-8')
