# %%
import pandas as pd
import spacy
from spacy import displacy
from spacy import tokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Load the NER model
nlp = spacy.load("en_core_web_sm")

# Load the sentiment analyzer
sid = SentimentIntensityAnalyzer()

# %%
#Doing Sentiment Analysis Pre Trial 
#We are doing this monthly for the time periods of  
#Jan
#Feb 
#March
#April 1st-10th April

# %%
#reading pre trial data set
df = pd.read_csv('PRE 2022 Twitter Tweets Jan-April_Amber Heard Data.csv')
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2639686265.py:2: DtypeWarning: Columns (0,4,5,25,29,30,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('PRE 2022 Twitter Tweets Jan-April_Amber Heard Data.csv')

# %%
#getting english tweets from the pre trial data set
df_en = df[df["lang"] == "en"]
df_en
# Out:
#                        id_str                 created_at  \
# 0       1477504983130116096.0  2022-01-02 05:00:13+00:00
# 1       1477503751716065280.0  2022-01-02 04:55:19+00:00
# 2       1477499814719983616.0  2022-01-02 04:39:41+00:00
# 3       1477497740498292736.0  2022-01-02 04:31:26+00:00
# 4       1477496477484212224.0  2022-01-02 04:26:25+00:00
# ...                       ...                        ...
# 508241    1515570192960659460  2022-04-17 05:57:46+00:00
# 508242    1515569901158600704  2022-04-17 05:56:37+00:00
# 508243    1515569890391961601  2022-04-17 05:56:34+00:00
# 508245    1515569604818575368  2022-04-17 05:55:26+00:00
# 508246    1515569491513589763  2022-04-17 05:54:59+00:00
#
#                                                 full_text lang  \
# 0       @la77465262 @Melinda15199317 @Dior So why is #...   en
# 1       Only thing I want them to leave alone is the f...   en
# 2       @soldierboy43001 @ZakReckless Yeah but Snyder ...   en
# ...

# %%
#making a data frame from the january tweets 
df_jan = df_en[(df_en['created_at'] > '2022-01-01') & (df_en['created_at'] < '2022-02-01')]
df_jan
# Out:
#                       id_str                 created_at  \
# 0      1477504983130116096.0  2022-01-02 05:00:13+00:00
# 1      1477503751716065280.0  2022-01-02 04:55:19+00:00
# 2      1477499814719983616.0  2022-01-02 04:39:41+00:00
# 3      1477497740498292736.0  2022-01-02 04:31:26+00:00
# 4      1477496477484212224.0  2022-01-02 04:26:25+00:00
# ...                      ...                        ...
# 18895    1479736326085824518  2022-01-08 08:46:46+00:00
# 18896    1479735816800944132  2022-01-08 08:44:45+00:00
# 18897    1479735675800985604  2022-01-08 08:44:11+00:00
# 18898    1479735049427857408  2022-01-08 08:41:42+00:00
# 18899    1479734629041061889  2022-01-08 08:40:02+00:00
#
#                                                full_text lang  \
# 0      @la77465262 @Melinda15199317 @Dior So why is #...   en
# 1      Only thing I want them to leave alone is the f...   en
# 2      @soldierboy43001 @ZakReckless Yeah but Snyder ...   en
# ...

# %%
#getting sentiment count in jan and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jan[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_jan.groupby(df_jan.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1079665378.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jan[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1079665378.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jan[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    1001
# ...

# %%
#labelling sentiment for each tweet in jan
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jan[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\3638635570.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jan[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting jan data with labels into csv 
df_jan.to_csv('jan_labelled.csv', index=False, encoding='utf-8')

# %%
#making a data frame from the febuary tweets 
df_feb = df_en[(df_en['created_at'] > '2022-02-01') & (df_en['created_at'] < '2022-03-01')]
df_feb
# Out:
#                     id_str                 created_at  \
# 18900  1495987453118885891  2022-02-22 05:02:57+00:00
# 18901  1495987275146174465  2022-02-22 05:02:15+00:00
# 18902  1495987151124807686  2022-02-22 05:01:45+00:00
# 18903  1495986895540662275  2022-02-22 05:00:44+00:00
# 18908  1495975430741970945  2022-02-22 04:15:11+00:00
# ...                    ...                        ...
# 40712  1495111519754985477  2022-02-19 19:02:18+00:00
# 40713  1495111428948348929  2022-02-19 19:01:57+00:00
# 40714  1495111212492804101  2022-02-19 19:01:05+00:00
# 40715  1495110385631993859  2022-02-19 18:57:48+00:00
# 40716  1495109777457876992  2022-02-19 18:55:23+00:00
#
#                                                full_text lang  \
# 18900  4. My vote for #Minamata\n#OscarsFanFavorite \...   en
# 18901  3. My vote for #Minamata\n#OscarsFanFavorite \...   en
# 18902  2. My vote for #Minamata\n#OscarsFanFavorite \...   en
# 18903  1. My vote for #Minamata\n#OscarsFanFavorite \...   en
# ...

# %%
#getting sentiment count in feb and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_feb[f"{entity} sentiment"] = df_feb['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_feb.groupby(df_feb.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1749807015.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feb[f"{entity} sentiment"] = df_feb['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    968
# neutral     883
# positive    743
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    2868
# positive    1759
# neutral     1089
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1749807015.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in feb
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_feb[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\3886753261.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feb[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting feb data with labels into csv 
df_feb.to_csv('feb_labelled.csv', index=False, encoding='utf-8')

# %%
#making a data frame from the march tweets 
df_mar = df_en[(df_en['created_at'] > '2022-03-01') & (df_en['created_at'] < '2022-04-01')]
df_mar
# Out:
#                     id_str                 created_at  \
# 40717  1501160198202961920  2022-03-08 11:37:36+00:00
# 40718  1501157581112418313  2022-03-08 11:27:12+00:00
# 40719  1501156722399973378  2022-03-08 11:23:47+00:00
# 40720  1501156257751007232  2022-03-08 11:21:56+00:00
# 40721  1501156224481517568  2022-03-08 11:21:48+00:00
# ...                    ...                        ...
# 66897  1504348904027930624  2022-03-17 06:48:22+00:00
# 66900  1504348565723828224  2022-03-17 06:47:02+00:00
# 66902  1504347838733561856  2022-03-17 06:44:08+00:00
# 66903  1504346634422992898  2022-03-17 06:39:21+00:00
# 66904  1504344863038394371  2022-03-17 06:32:19+00:00
#
#                                                full_text lang  \
# 40717  @la77465262 Just because she is a woman should...   en
# 40718  We aren’t just talking a violent phase over a ...   en
# 40719  After claiming he would, he had medical record...   en
# 40720  Judge pls see THIS . \n#JusticeForJohnnyDeppVi...   en
# ...

# %%
#getting sentiment count in mar and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_mar[f"{entity} sentiment"] = df_mar['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_mar.groupby(df_mar.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\3490190444.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mar[f"{entity} sentiment"] = df_mar['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    1828
# neutral     1267
# positive    1135
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    4633
# positive    2781
# neutral     1993
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\3490190444.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in mar
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_mar[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2030015281.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mar[f"{entity} sentiment"] = df_jan['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting mar data with labels into csv 
df_mar.to_csv('mar_labelled.csv', index=False, encoding='utf-8')

# %%
#making a data frame from the april tweets 
df_apr_pre = df_en[(df_en['created_at'] > '2022-04-01') & (df_en['created_at'] < '2022-04-11')]
df_apr_pre
# Out:
#                      id_str                 created_at  \
# 81886   1510206814692036608  2022-04-02 10:45:37+00:00
# 81888   1510204553186140164  2022-04-02 10:36:38+00:00
# 81889   1510204149094404099  2022-04-02 10:35:02+00:00
# 81890   1510203910971326464  2022-04-02 10:34:05+00:00
# 81891   1510202907970445326  2022-04-02 10:30:06+00:00
# ...                     ...                        ...
# 503668  1510857771671076868  2022-04-04 05:52:17+00:00
# 503669  1510855684820291587  2022-04-04 05:44:00+00:00
# 503670  1510855648535322625  2022-04-04 05:43:51+00:00
# 503672  1510855084028137472  2022-04-04 05:41:37+00:00
# 503674  1510854685263077377  2022-04-04 05:40:01+00:00
#
#                                                 full_text lang  \
# 81886   @BBCWorld Hey, if Amber Heard can still have a...   en
# 81888   Is it really the face of a traumatized and ter...   en
# 81889   Mmh the "victim" telling the "abuser": stop ru...   en
# ...

# %%
#getting sentiment count in apr and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_pre[f"{entity} sentiment"] = df_apr_pre['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_apr_pre.groupby(df_apr_pre.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2742009560.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_pre[f"{entity} sentiment"] = df_apr_pre['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    1391
# positive     922
# neutral      852
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    3940
# positive    2126
# neutral     2116
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2742009560.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in apr
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_pre[f"{entity} sentiment"] = df_apr_pre['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1846125384.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_pre[f"{entity} sentiment"] = df_apr_pre['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting apr data pre trial with labels into csv 
df_apr_pre.to_csv('df_apr_pre.csv', index=False, encoding='utf-8')

# %%
#Doing Sentiment Analysis During the Trial
#We are doing this bi-weekly

#Apr 11th - 17th apr
#Apr 18thapr - 30apr


#May 1st - 14th may
#May 15th May- 1st Jun

# %%
#reading during trial data set

#apr in general
df_apr_post = pd.read_excel('DURING 11-30 Apr Twitter Data.xlsx')

#Apr 11th - 17th apr
df_apr_biweekly1 = df_apr_post[(df_apr_post['created_at'] > '2022-04-10') & (df_apr_post['created_at'] < '2022-04-18')]

#Apr 18thapr - 30apr
df_apr_biweekly2 = df_apr_post[(df_apr_post['created_at'] > '2022-04-18') & (df_apr_post['created_at'] < '2022-05-01')]

#May in general 
df_may_post = pd.read_excel('DURING 1May - 1Jun Twitter Data.xlsx')


#May 1st - 14th may
df_may_biweekly1 = df_may_post[(df_may_post['created_at'] > '2022-04-30') & (df_may_post['created_at'] < '2022-05-15')]


#May 15th May- 1st Jun
df_may_biweekly2 = df_may_post[(df_may_post['created_at'] > '2022-05-15') & (df_may_post['created_at'] < '2022-06-02')]

# %%
#getting sentiment count in 11-17 apr and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_biweekly1[f"{entity} sentiment"] = df_apr_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_apr_biweekly1.groupby(df_apr_biweekly1.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1750845248.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_biweekly1[f"{entity} sentiment"] = df_apr_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    4236
# neutral     2793
# positive    2030
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    9532
# neutral     5072
# positive    4544
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1750845248.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in april 11-17
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_biweekly1[f"{entity} sentiment"] = df_apr_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\4183142835.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_biweekly1[f"{entity} sentiment"] = df_apr_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting apr data during trial in 11-17 with labels into csv 
df_apr_biweekly1.to_csv('df_apr_biweekly1.csv', index=False, encoding='utf-8')

# %%
#getting sentiment count in  18-30 apr and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_biweekly2[f"{entity} sentiment"] = df_apr_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_apr_biweekly2.groupby(df_apr_biweekly2.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1056005394.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_biweekly2[f"{entity} sentiment"] = df_apr_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    9095
# neutral     5129
# positive    4927
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    23682
# positive    15224
# neutral     12945
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\1056005394.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in april 18-30
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_apr_biweekly2[f"{entity} sentiment"] = df_apr_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2526809893.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apr_biweekly2[f"{entity} sentiment"] = df_apr_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting apr data during trial in apr 18-30 with labels into csv 
df_apr_biweekly2.to_csv('df_apr_biweekly2.csv', index=False, encoding='utf-8')

# %%
#getting sentiment count in may 1st - 14th may and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_may_biweekly1[f"{entity} sentiment"] = df_may_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_may_biweekly1.groupby(df_may_biweekly1.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2063556886.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_may_biweekly1[f"{entity} sentiment"] = df_may_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    7867
# positive    4645
# neutral     4479
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    25351
# positive    16690
# neutral     13955
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2063556886.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in may 1st -14
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_may_biweekly1[f"{entity} sentiment"] = df_may_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\2252204663.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_may_biweekly1[f"{entity} sentiment"] = df_may_biweekly1['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting may data during trial in may 1st-15th with labels into csv 
df_may_biweekly1.to_csv('df_may_biweekly1.csv', index=False, encoding='utf-8')

# %%
#getting sentiment count in may 15th - 1st june and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_may_biweekly2[f"{entity} sentiment"] = df_may_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_may_biweekly2.groupby(df_may_biweekly2.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\4187761349.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_may_biweekly2[f"{entity} sentiment"] = df_may_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
# Sentiment counts for Johnny Depp:
# negative    9579
# positive    6879
# neutral     5626
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    31439
# positive    20586
# neutral     16314
# Name: Amber Heard sentiment, dtype: int64
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\4187761349.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#labelling sentiment for each tweet in may 15 - 1st june
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_may_biweekly2[f"{entity} sentiment"] = df_may_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")
# Out:
# C:\Users\hazel\AppData\Local\Temp\ipykernel_13060\436887605.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_may_biweekly2[f"{entity} sentiment"] = df_may_biweekly2['full_text'].apply(lambda x: extract_sentiment(x, entity))

# %%
#exporting may data during trial in may 15t-1st june with labels into csv 
df_may_biweekly2.to_csv('df_may_biweekly2.csv', index=False, encoding='utf-8')

# %%
#Doing Sentiment Analysis Post Trial 
#We are doing this monthly 

#2nd June - 30th June 
df_jun = pd.read_excel('POST 2-30 Jun Twitter Data.xlsx')

#July 
df_jul = pd.read_excel('POST 1-31 Jul Twitter Data.xlsx')

#Aug
df_aug = pd.read_excel('POST 1-31 Aug Twitter Data.xlsx')

# %%
#getting sentiment count in 2nd June - 30th June and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jun[f"{entity} sentiment"] = df_jun['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_jun.groupby(df_jun.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# Sentiment counts for Johnny Depp:
# negative    11540
# positive     9854
# neutral      5556
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    47427
# positive    34969
# neutral     25628
# Name: Amber Heard sentiment, dtype: int64

# %%
#labelling sentiment for each tweet in june 2-30
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jun[f"{entity} sentiment"] = df_jun['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# %%
#exporting june data during trial with labels into csv 
df_jun.to_csv('df_jun.csv', index=False, encoding='utf-8')

# %%
#getting sentiment count jul and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jul[f"{entity} sentiment"] = df_jul['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_jul.groupby(df_jul.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# Sentiment counts for Johnny Depp:
# negative    7563
# positive    5861
# neutral     3549
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    28554
# positive    20572
# neutral     14514
# Name: Amber Heard sentiment, dtype: int64

# %%
#labelling sentiment for each tweet in jul
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_jul[f"{entity} sentiment"] = df_jul['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# %%
#exporting jul data during trial with labels into csv 
df_jul.to_csv('df_jul.csv', index=False, encoding='utf-8')

# %%
#getting sentiment count aug and who it is directed towards

# Define a function to extract named entities and classify sentiment for a tweet
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return None

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_aug[f"{entity} sentiment"] = df_aug['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# Group by the index of the dataframe and sum the sentiment counts for each entity
sentiment_counts = df_aug.groupby(df_aug.index)[sentiment_cols].sum()

# Print the sentiment counts for Johnny Depp and Amber Heard
depp_sentiment_counts = sentiment_counts['Johnny Depp sentiment'].value_counts().drop(0)
heard_sentiment_counts = sentiment_counts['Amber Heard sentiment'].value_counts().drop(0)
print(f"Sentiment counts for Johnny Depp:\n{depp_sentiment_counts}\n")
print(f"Sentiment counts for Amber Heard:\n{heard_sentiment_counts}")
# Out:
# Sentiment counts for Johnny Depp:
# negative    6055
# positive    3378
# neutral     2534
# Name: Johnny Depp sentiment, dtype: int64
#
# Sentiment counts for Amber Heard:
# negative    25725
# positive    16812
# neutral     11284
# Name: Amber Heard sentiment, dtype: int64

# %%
#labelling sentiment for each tweet in aug
def extract_sentiment(text, entity):
    sentiment_scores = sid.polarity_scores(text)
    if entity.lower() in text.lower():
        if sentiment_scores['compound'] > 0:
            return 'positive'
        elif sentiment_scores['compound'] < 0:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'not mentioned'

# Apply named entity recognition and sentiment analysis to each tweet in the dataframe
sentiment_cols = []
for entity in ['Johnny Depp', 'Amber Heard']:
    df_aug[f"{entity} sentiment"] = df_aug['full_text'].apply(lambda x: extract_sentiment(x, entity))
    sentiment_cols.append(f"{entity} sentiment")

# %%
#exporting jul data during trial with labels into csv 
df_aug.to_csv('df_aug.csv', index=False, encoding='utf-8')
